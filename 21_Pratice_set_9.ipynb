# %% [markdown]
# ## 1. Write a program to read the text from a given file ‘poems.txt’ and find out whether it contains the word ‘twinkle’.

# %%
with open ("poems.txt") as f:
    data = f.read()
    

if("twinkle" in data):
    print(True)
else:
    False
# Out:
# True

# %% [markdown]
# ## 2. The game() function in a program lets a user play a game and returns the score as an integer. You need to read a file ‘Hi-score.txt’ which is either blank or contains the previous Hi-score. You need to write a program to update the Hi score whenever the game() function breaks the Hi-score.

# %%
import random

def game():
    print("You are playing game..")
    score = random.randint(10,101)
    print(f"Your score : {score}")
    with open("hi_score.txt") as f:
        hs = f.read()
        if(hs!=""):
            hs = int(hs)
        else:
            hs = 0

    
    if(score>hs):
        with open("hi_score.txt", "w") as f:
            f.write(str(score))

    return score


game()
# Out:
# You are playing game..
# Your score : 41
# 41

# %% [markdown]
# ## 3. Write a program to generate multiplication tables from 2 to 20 and write it to the different files. Place these files in a folder for a 13 – year old.

# %%
def gentable(n):
    table = ""
    for i in range(1,11):
        table = table + f"{n} X {i} = {n*i}\n"

    with open (f"tables/table_{n}", "w")as f:
        f.write(table)




for i in range(2,21):
    gentable(i)

# %% [markdown]
# ## 4. A file contains a word “Donkey” multiple times. You need to write a program which replace this word with ##### by updating the same file.

# %%
with open("donkey.txt") as f:
    content = f.read()

NewC = content.replace("DONKEY", "######")

with open("donkey.txt", "w") as f:
    f.write(NewC)

# %% [markdown]
# ## 5. Repeat program 4 for a list of such words to be censored.

# %%
censored = ["Donkey","bad","rat"]

with open("donkey.txt") as f:
    content = f.read()

for word in censored:
    content = content.replace(word, "#" * len(word)) 

with open("donkey.txt", "w") as f:
    f.write(content)

# %% [markdown]
# ## 6. Write a program to mine a log file and find out whether it contains ‘python’.

# %%
with open("log.txt") as f:
    data = f.read()

if ("python" in data):
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# ## 7. Write a program to find out the line number where python is present from ques 6.

# %%
with open("log.txt") as f:
    lines = f.readlines()

lineno =  1
for i in lines:
    if ("python" in i):
        print(f"Python is detected on : {lineno}")
        break
    lineno = lineno + 1
     
else:
    print("No Python")
# Out:
# Python is detected on : 4

# %% [markdown]
# ## 8. Write a program to make a copy of a text file “log. txt”

# %%
with open ("log.txt")as f:
    data = f.read()

with open ("log_copy.txt", "w")as f:
    f.write(data)

# %% [markdown]
# ## 9. Write a program to find out whether a file is identical & matches the content of another file.

# %%
with open ("20_text.txt") as f:
    data = f.read()

with open ("log.txt") as f:
    content = f.read()


if(data == content):
    print("Yes file is identical & matches the content of another file.")
else:
    print("No not a Copy")
# Out:
# No not a Copy

# %%
with open ("log.txt") as f:
    content = f.read()

with open ("log_copy.txt") as f:
    content2 = f.read()

if(content == content2):
    print("Yes file is identical & matches the content of another file.")
else:
    print("No not a Copy")
# Out:
# Yes file is identical & matches the content of another file.

# %% [markdown]
# ## 10. Write a program to wipe out the content of a file using python.

# %%
data = ""

with open ("content.txt", "w")as f:
    f.write(data) #or    f.write("")

# %% [markdown]
# ## 11. Write a python program to rename a file to “renamed_by_ python.txt.

# %%
with open ("old.txt") as f:
    content = f.read()

with open ("renamed_by_ python.txt", "w")as f:
    f.write(content)
